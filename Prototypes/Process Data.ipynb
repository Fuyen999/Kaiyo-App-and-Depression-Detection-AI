# %%
CUSTOMISED_STOP_WORDS = set(
    """
    a about above across after afterwards again all almost alone along
    already also although always am among amongst amount an and another any anyhow
    anyone anything anyway anywhere are around as at
    back be became because become becomes becoming been before beforehand behind
    being below beside besides between beyond both bottom but by
    call can cannot ca could
    did do does doing done down due during
    each eight either eleven else elsewhere empty enough even ever every
    everyone everything everywhere except
    few fifteen fifty first five for former formerly forty four from front full
    further
    get give go
    had has have he hence her here hereafter hereby herein hereupon hers herself
    him himself his how however hundred
    i if in indeed into is it its itself
    keep
    last latter latterly least less
    just
    made make many may me meanwhile might mine more moreover most mostly move much
    must my myself
    name namely neither never nevertheless next nine now
    of off often on once one only onto or other others otherwise our ours ourselves
    out over own
    part per perhaps please put
    quite
    rather re really regarding
    same say see seem seemed seeming seems serious several she should show side
    since six sixty so some somehow someone something sometime sometimes somewhere
    still such
    take ten than that the their them themselves then thence there thereafter
    thereby therefore therein thereupon these they third this those though three
    through throughout thru thus to together too top toward towards twelve twenty
    two
    under until up unless upon us used using
    various very very via was we well were what whatever when whence whenever where
    whereafter whereas whereby wherein whereupon wherever whether which while
    whither who whoever whole whom whose why will with within without would
    yet you your yours yourself yourselves
    """.split()
)

customised_contractions = ["'d", "'ll", "'m", "'re", "'s", "'ve"]
CUSTOMISED_STOP_WORDS.update(customised_contractions)

# %%
# run the commands below in terminal to install dependencies
# pip install spacy
# python -m spacy download en
import spacy
from spacy.lang.en import English
from spacy.lang.en.stop_words import STOP_WORDS
import string

nlp_sw = English()
nlp_n = spacy.load("en_core_web_sm")

removable_char = list(string.punctuation) + ["\n", "\r"]

# text arguement in string
# remove stop words of the provided text
# return a list of words in small letters in the text without stop words and punctuations
def remove_stop_words(text):
    text = text.lower()
    token_doc = nlp_sw(text)
    clean_text = []
    for token in token_doc:
        token_text = token.text
        token_text = token_text.replace(" ", "")
        token_text = "not" if token_text == "n't" else token_text
        if not(token_text in CUSTOMISED_STOP_WORDS or token_text in removable_char):
            if token_text and not(token_text.isspace()):
                tmp_text = token_text[1:] if token_text[0] in removable_char else token_text
                if tmp_text and not(tmp_text.isspace()):
                    clean_text.append(tmp_text)
    return clean_text

# text arguement in string
# normalise the text
# return a list of words in small letters in the normalised text
def normalise_text(text):
    text = text.lower()
    token_doc = nlp_n(text)
    normalised_text = []
    for token in token_doc:
        lemma = token.lemma_
        if not(lemma == "-PRON-"):
            normalised_text.append(lemma)
    return normalised_text

# %%
import pandas as pd
df = pd.read_csv('training_data.csv')
df
# Out:
#          Label                                          Sentences
# 0            0  is upset that he can't update his Facebook by ...
# 1            0  @Kenichan I dived many times for the ball. Man...
# 2            0    my whole body feels itchy and like its on fire
# 3            0  @nationwideclass no, it's not behaving at all....
# 4            0                      @Kwesidei not the whole crew
# ...        ...                                                ...
# 1599994      4  Just woke up. Having no school is the best fee...
# 1599995      4  TheWDB.com - Very cool to hear old Walt interv...
# 1599996      4  Are you ready for your MoJo Makeover? Ask me f...
# 1599997      4  Happy 38th Birthday to my boo of alll time!!! ...
# 1599998      4  happy #charitytuesday @theNSPCC @SparksCharity...
#
# [1599999 rows x 2 columns]

# %%
# 0 = negative, 2 = neutral, 4 = positive
number_of_data = 1500000
data_negative = df[df.Label == 0][:int(number_of_data/2)]
data_positive = df[df.Label == 4][:int(number_of_data/2)]
data_positive["Label"] = 1
df_row_merged = pd.concat([data_negative, data_positive], ignore_index=True)
df_row_merged
# Out:
#          Label                                          Sentences
# 0            0  is upset that he can't update his Facebook by ...
# 1            0  @Kenichan I dived many times for the ball. Man...
# 2            0    my whole body feels itchy and like its on fire
# 3            0  @nationwideclass no, it's not behaving at all....
# 4            0                      @Kwesidei not the whole crew
# ...        ...                                                ...
# 1499995      1  ... im so happy for 1,2 ,3 ...oh 20 days my mr...
# 1499996      1  Enjoying In Wonderful Day In Vegas!!! It's SOO...
# 1499997      1  everybody else sleeping, but me.. no im not go...
# 1499998      1                               @gley10 get on aim?
# 1499999      1  super stoked for 6/26! aka day of nothing pers...
#
# [1500000 rows x 2 columns]

# %%
clean_data = df_row_merged.sample(frac=1).reset_index(drop=True)
clean_data
# Out:
#          Label                                          Sentences
# 0            0                     I think i hate summer.......
# 1            1                        time for subway and a run!
# 2            0           i feel terrible.. i am definitely sick.
# 3            0  I can't wait to see UP! How dare @katymoe have...
# 4            0  battery is low_20%_#iphone 3g is a realy batte...
# ...        ...                                                ...
# 1499995      1  enjoying all the new but old dub and funk i've...
# 1499996      1  The weather is awesome   http://twitpic.com/6cbuc
# 1499997      1                                     with Margaret
# 1499998      0  @TheDannyNoriega you and chris are so sweet yo...
# 1499999      0  @springlamb fingers and toes crossed that its ...
#
# [1500000 rows x 2 columns]

# %%
# remove url in tweets
# remove tag (@) in tweets
# remove hashtags (#) in tweets
# remove stopwords
# normalise text
# this cell might take some time to run, be patient
import re
import string

url_pattern = re.compile(".*https?:\/\/")
hashtag_pattern = re.compile("#[a-z\d-]+")
tag_pattern = re.compile("^@")
punc = string.punctuation
punc = punc.replace("-", "")
punc += "“”"
punc = punc.replace ("'","")

pd.options.mode.chained_assignment = None

def process_text(text):
    tmp_no_url_hashtag = []
    for word in re.split(' |\r|\n', text):
        if url_pattern.match(word) or tag_pattern.match(word) or hashtag_pattern.match(word):
            continue
        else:
            clean_word = word.translate(str.maketrans("","", punc))
            clean_word = clean_word.replace("’","'")
            tmp_no_url_hashtag.append(clean_word)
    tmp = " ".join(tmp_no_url_hashtag)
    without_stopwords = " ".join(remove_stop_words(tmp))
    processed = " ".join(normalise_text(without_stopwords))
    return processed

for i in range (len(clean_data["Sentences"])):
    clean_data["Sentences"][i] = process_text(clean_data["Sentences"][i])
    if i % 1000 == 0:
        print ("Processing", i, "unit")
# Out:
# Processing 0 unit
# Processing 1000 unit
# Processing 2000 unit
# Processing 3000 unit
# Processing 4000 unit
# Processing 5000 unit
# Processing 6000 unit
# Processing 7000 unit
# Processing 8000 unit
# Processing 9000 unit
# Processing 10000 unit
# Processing 11000 unit
# Processing 12000 unit
# Processing 13000 unit
# Processing 14000 unit
# Processing 15000 unit
# Processing 16000 unit
# Processing 17000 unit
# Processing 18000 unit
# Processing 19000 unit
# Processing 20000 unit
# Processing 21000 unit
# Processing 22000 unit
# Processing 23000 unit
# Processing 24000 unit
# Processing 25000 unit
# Processing 26000 unit
# Processing 27000 unit
# Processing 28000 unit
# Processing 29000 unit
# Processing 30000 unit
# Processing 31000 unit
# Processing 32000 unit
# Processing 33000 unit
# Processing 34000 unit
# Processing 35000 unit
# Processing 36000 unit
# Processing 37000 unit
# Processing 38000 unit
# Processing 39000 unit
# Processing 40000 unit
# Processing 41000 unit
# Processing 42000 unit
# Processing 43000 unit
# Processing 44000 unit
# Processing 45000 unit
# Processing 46000 unit
# Processing 47000 unit
# Processing 48000 unit
# Processing 49000 unit
# Processing 50000 unit
# Processing 51000 unit
# Processing 52000 unit
# Processing 53000 unit
# Processing 54000 unit
# Processing 55000 unit
# Processing 56000 unit
# Processing 57000 unit
# Processing 58000 unit
# Processing 59000 unit
# Processing 60000 unit
# Processing 61000 unit
# Processing 62000 unit
# Processing 63000 unit
# Processing 64000 unit
# Processing 65000 unit
# Processing 66000 unit
# Processing 67000 unit
# Processing 68000 unit
# Processing 69000 unit
# Processing 70000 unit
# Processing 71000 unit
# Processing 72000 unit
# Processing 73000 unit
# Processing 74000 unit
# Processing 75000 unit
# Processing 76000 unit
# Processing 77000 unit
# Processing 78000 unit
# Processing 79000 unit
# Processing 80000 unit
# Processing 81000 unit
# Processing 82000 unit
# Processing 83000 unit
# Processing 84000 unit
# Processing 85000 unit
# Processing 86000 unit
# Processing 87000 unit
# Processing 88000 unit
# Processing 89000 unit
# Processing 90000 unit
# Processing 91000 unit
# Processing 92000 unit
# Processing 93000 unit
# Processing 94000 unit
# Processing 95000 unit
# Processing 96000 unit
# Processing 97000 unit
# Processing 98000 unit
# Processing 99000 unit
# Processing 100000 unit
# Processing 101000 unit
# Processing 102000 unit
# Processing 103000 unit
# Processing 104000 unit
# Processing 105000 unit
# Processing 106000 unit
# Processing 107000 unit
# Processing 108000 unit
# Processing 109000 unit
# Processing 110000 unit
# Processing 111000 unit
# Processing 112000 unit
# Processing 113000 unit
# Processing 114000 unit
# Processing 115000 unit
# Processing 116000 unit
# Processing 117000 unit
# Processing 118000 unit
# Processing 119000 unit
# Processing 120000 unit
# Processing 121000 unit
# Processing 122000 unit
# Processing 123000 unit
# Processing 124000 unit
# Processing 125000 unit
# Processing 126000 unit
# Processing 127000 unit
# Processing 128000 unit
# Processing 129000 unit
# Processing 130000 unit
# Processing 131000 unit
# Processing 132000 unit
# Processing 133000 unit
# Processing 134000 unit
# Processing 135000 unit
# Processing 136000 unit
# Processing 137000 unit
# Processing 138000 unit
# Processing 139000 unit
# Processing 140000 unit
# Processing 141000 unit
# Processing 142000 unit
# Processing 143000 unit
# Processing 144000 unit
# Processing 145000 unit
# Processing 146000 unit
# Processing 147000 unit
# Processing 148000 unit
# Processing 149000 unit
# Processing 150000 unit
# Processing 151000 unit
# Processing 152000 unit
# Processing 153000 unit
# Processing 154000 unit
# Processing 155000 unit
# Processing 156000 unit
# Processing 157000 unit
# Processing 158000 unit
# Processing 159000 unit
# Processing 160000 unit
# Processing 161000 unit
# Processing 162000 unit
# Processing 163000 unit
# Processing 164000 unit
# Processing 165000 unit
# Processing 166000 unit
# Processing 167000 unit
# Processing 168000 unit
# Processing 169000 unit
# Processing 170000 unit
# Processing 171000 unit
# Processing 172000 unit
# Processing 173000 unit
# Processing 174000 unit
# Processing 175000 unit
# Processing 176000 unit
# Processing 177000 unit
# Processing 178000 unit
# Processing 179000 unit
# Processing 180000 unit
# Processing 181000 unit
# Processing 182000 unit
# Processing 183000 unit
# Processing 184000 unit
# Processing 185000 unit
# Processing 186000 unit
# Processing 187000 unit
# Processing 188000 unit
# Processing 189000 unit
# Processing 190000 unit
# Processing 191000 unit
# Processing 192000 unit
# Processing 193000 unit
# Processing 194000 unit
# Processing 195000 unit
# Processing 196000 unit
# Processing 197000 unit
# Processing 198000 unit
# Processing 199000 unit
# Processing 200000 unit
# Processing 201000 unit
# Processing 202000 unit
# Processing 203000 unit
# Processing 204000 unit
# Processing 205000 unit
# Processing 206000 unit
# Processing 207000 unit
# Processing 208000 unit
# Processing 209000 unit
# Processing 210000 unit
# Processing 211000 unit
# Processing 212000 unit
# Processing 213000 unit
# Processing 214000 unit
# Processing 215000 unit
# Processing 216000 unit
# Processing 217000 unit
# Processing 218000 unit
# Processing 219000 unit
# Processing 220000 unit
# Processing 221000 unit
# Processing 222000 unit
# Processing 223000 unit
# Processing 224000 unit
# Processing 225000 unit
# Processing 226000 unit
# Processing 227000 unit
# Processing 228000 unit
# Processing 229000 unit
# Processing 230000 unit
# Processing 231000 unit
# Processing 232000 unit
# Processing 233000 unit
# Processing 234000 unit
# Processing 235000 unit
# Processing 236000 unit
# Processing 237000 unit
# Processing 238000 unit
# Processing 239000 unit
# Processing 240000 unit
# Processing 241000 unit
# Processing 242000 unit
# Processing 243000 unit
# Processing 244000 unit
# Processing 245000 unit
# Processing 246000 unit
# Processing 247000 unit
# Processing 248000 unit
# Processing 249000 unit
# Processing 250000 unit
# Processing 251000 unit
# Processing 252000 unit
# Processing 253000 unit
# Processing 254000 unit
# Processing 255000 unit
# Processing 256000 unit
# Processing 257000 unit
# Processing 258000 unit
# Processing 259000 unit
# Processing 260000 unit
# Processing 261000 unit
# Processing 262000 unit
# Processing 263000 unit
# Processing 264000 unit
# Processing 265000 unit
# Processing 266000 unit
# Processing 267000 unit
# Processing 268000 unit
# Processing 269000 unit
# Processing 270000 unit
# Processing 271000 unit
# Processing 272000 unit
# Processing 273000 unit
# Processing 274000 unit
# Processing 275000 unit
# Processing 276000 unit
# Processing 277000 unit
# Processing 278000 unit
# Processing 279000 unit
# Processing 280000 unit
# Processing 281000 unit
# Processing 282000 unit
# Processing 283000 unit
# Processing 284000 unit
# Processing 285000 unit
# Processing 286000 unit
# Processing 287000 unit
# Processing 288000 unit
# Processing 289000 unit
# Processing 290000 unit
# Processing 291000 unit
# Processing 292000 unit
# Processing 293000 unit
# Processing 294000 unit
# Processing 295000 unit
# Processing 296000 unit
# Processing 297000 unit
# Processing 298000 unit
# Processing 299000 unit
# Processing 300000 unit
# Processing 301000 unit
# Processing 302000 unit
# Processing 303000 unit
# Processing 304000 unit
# Processing 305000 unit
# Processing 306000 unit
# Processing 307000 unit
# Processing 308000 unit
# Processing 309000 unit
# Processing 310000 unit
# Processing 311000 unit
# Processing 312000 unit
# Processing 313000 unit
# Processing 314000 unit
# Processing 315000 unit
# Processing 316000 unit
# Processing 317000 unit
# Processing 318000 unit
# Processing 319000 unit
# Processing 320000 unit
# Processing 321000 unit
# Processing 322000 unit
# Processing 323000 unit
# Processing 324000 unit
# Processing 325000 unit
# Processing 326000 unit
# Processing 327000 unit
# Processing 328000 unit
# Processing 329000 unit
# Processing 330000 unit
# Processing 331000 unit
# Processing 332000 unit
# Processing 333000 unit
# Processing 334000 unit
# Processing 335000 unit
# Processing 336000 unit
# Processing 337000 unit
# Processing 338000 unit
# Processing 339000 unit
# Processing 340000 unit
# Processing 341000 unit
# Processing 342000 unit
# Processing 343000 unit
# Processing 344000 unit
# Processing 345000 unit
# Processing 346000 unit
# Processing 347000 unit
# Processing 348000 unit
# Processing 349000 unit
# Processing 350000 unit
# Processing 351000 unit
# Processing 352000 unit
# Processing 353000 unit
# Processing 354000 unit
# Processing 355000 unit
# Processing 356000 unit
# Processing 357000 unit
# Processing 358000 unit
# Processing 359000 unit
# Processing 360000 unit
# Processing 361000 unit
# Processing 362000 unit
# Processing 363000 unit
# Processing 364000 unit
# Processing 365000 unit
# Processing 366000 unit
# Processing 367000 unit
# Processing 368000 unit
# Processing 369000 unit
# Processing 370000 unit
# Processing 371000 unit
# Processing 372000 unit
# Processing 373000 unit
# Processing 374000 unit
# Processing 375000 unit
# Processing 376000 unit
# Processing 377000 unit
# Processing 378000 unit
# Processing 379000 unit
# Processing 380000 unit
# Processing 381000 unit
# Processing 382000 unit
# Processing 383000 unit
# Processing 384000 unit
# Processing 385000 unit
# Processing 386000 unit
# Processing 387000 unit
# Processing 388000 unit
# Processing 389000 unit
# Processing 390000 unit
# Processing 391000 unit
# Processing 392000 unit
# Processing 393000 unit
# Processing 394000 unit
# Processing 395000 unit
# Processing 396000 unit
# Processing 397000 unit
# Processing 398000 unit
# Processing 399000 unit
# Processing 400000 unit
# Processing 401000 unit
# Processing 402000 unit
# Processing 403000 unit
# Processing 404000 unit
# Processing 405000 unit
# Processing 406000 unit
# Processing 407000 unit
# Processing 408000 unit
# Processing 409000 unit
# Processing 410000 unit
# Processing 411000 unit
# Processing 412000 unit
# Processing 413000 unit
# Processing 414000 unit
# Processing 415000 unit
# Processing 416000 unit
# Processing 417000 unit
# Processing 418000 unit
# Processing 419000 unit
# Processing 420000 unit
# Processing 421000 unit
# Processing 422000 unit
# Processing 423000 unit
# Processing 424000 unit
# Processing 425000 unit
# Processing 426000 unit
# Processing 427000 unit
# Processing 428000 unit
# Processing 429000 unit
# Processing 430000 unit
# Processing 431000 unit
# Processing 432000 unit
# Processing 433000 unit
# Processing 434000 unit
# Processing 435000 unit
# Processing 436000 unit
# Processing 437000 unit
# Processing 438000 unit
# Processing 439000 unit
# Processing 440000 unit
# Processing 441000 unit
# Processing 442000 unit
# Processing 443000 unit
# Processing 444000 unit
# Processing 445000 unit
# Processing 446000 unit
# Processing 447000 unit
# Processing 448000 unit
# Processing 449000 unit
# Processing 450000 unit
# Processing 451000 unit
# Processing 452000 unit
# Processing 453000 unit
# Processing 454000 unit
# Processing 455000 unit
# Processing 456000 unit
# Processing 457000 unit
# Processing 458000 unit
# Processing 459000 unit
# Processing 460000 unit
# Processing 461000 unit
# Processing 462000 unit
# Processing 463000 unit
# Processing 464000 unit
# Processing 465000 unit
# Processing 466000 unit
# Processing 467000 unit
# Processing 468000 unit
# Processing 469000 unit
# Processing 470000 unit
# Processing 471000 unit
# Processing 472000 unit
# Processing 473000 unit
# Processing 474000 unit
# Processing 475000 unit
# Processing 476000 unit
# Processing 477000 unit
# Processing 478000 unit
# Processing 479000 unit
# Processing 480000 unit
# Processing 481000 unit
# Processing 482000 unit
# Processing 483000 unit
# Processing 484000 unit
# Processing 485000 unit
# Processing 486000 unit
# Processing 487000 unit
# Processing 488000 unit
# Processing 489000 unit
# Processing 490000 unit
# Processing 491000 unit
# Processing 492000 unit
# Processing 493000 unit
# Processing 494000 unit
# Processing 495000 unit
# Processing 496000 unit
# Processing 497000 unit
# Processing 498000 unit
# Processing 499000 unit
# Processing 500000 unit
# Processing 501000 unit
# Processing 502000 unit
# Processing 503000 unit
# Processing 504000 unit
# Processing 505000 unit
# Processing 506000 unit
# Processing 507000 unit
# Processing 508000 unit
# Processing 509000 unit
# Processing 510000 unit
# Processing 511000 unit
# Processing 512000 unit
# Processing 513000 unit
# Processing 514000 unit
# Processing 515000 unit
# Processing 516000 unit
# Processing 517000 unit
# Processing 518000 unit
# Processing 519000 unit
# Processing 520000 unit
# Processing 521000 unit
# Processing 522000 unit
# Processing 523000 unit
# Processing 524000 unit
# Processing 525000 unit
# Processing 526000 unit
# Processing 527000 unit
# Processing 528000 unit
# Processing 529000 unit
# Processing 530000 unit
# Processing 531000 unit
# Processing 532000 unit
# Processing 533000 unit
# Processing 534000 unit
# Processing 535000 unit
# Processing 536000 unit
# Processing 537000 unit
# Processing 538000 unit
# Processing 539000 unit
# Processing 540000 unit
# Processing 541000 unit
# Processing 542000 unit
# Processing 543000 unit
# Processing 544000 unit
# Processing 545000 unit
# Processing 546000 unit
# Processing 547000 unit
# Processing 548000 unit
# Processing 549000 unit
# Processing 550000 unit
# Processing 551000 unit
# Processing 552000 unit
# Processing 553000 unit
# Processing 554000 unit
# Processing 555000 unit
# Processing 556000 unit
# Processing 557000 unit
# Processing 558000 unit
# Processing 559000 unit
# Processing 560000 unit
# Processing 561000 unit
# Processing 562000 unit
# Processing 563000 unit
# Processing 564000 unit
# Processing 565000 unit
# Processing 566000 unit
# Processing 567000 unit
# Processing 568000 unit
# Processing 569000 unit
# Processing 570000 unit
# Processing 571000 unit
# Processing 572000 unit
# Processing 573000 unit
# Processing 574000 unit
# Processing 575000 unit
# Processing 576000 unit
# Processing 577000 unit
# Processing 578000 unit
# Processing 579000 unit
# Processing 580000 unit
# Processing 581000 unit
# Processing 582000 unit
# Processing 583000 unit
# Processing 584000 unit
# Processing 585000 unit
# Processing 586000 unit
# Processing 587000 unit
# Processing 588000 unit
# Processing 589000 unit
# Processing 590000 unit
# Processing 591000 unit
# Processing 592000 unit
# Processing 593000 unit
# Processing 594000 unit
# Processing 595000 unit
# Processing 596000 unit
# Processing 597000 unit
# Processing 598000 unit
# Processing 599000 unit
# Processing 600000 unit
# Processing 601000 unit
# Processing 602000 unit
# Processing 603000 unit
# Processing 604000 unit
# Processing 605000 unit
# Processing 606000 unit
# Processing 607000 unit
# Processing 608000 unit
# Processing 609000 unit
# Processing 610000 unit
# Processing 611000 unit
# Processing 612000 unit
# Processing 613000 unit
# Processing 614000 unit
# Processing 615000 unit
# Processing 616000 unit
# Processing 617000 unit
# Processing 618000 unit
# Processing 619000 unit
# Processing 620000 unit
# Processing 621000 unit
# Processing 622000 unit
# Processing 623000 unit
# Processing 624000 unit
# Processing 625000 unit
# Processing 626000 unit
# Processing 627000 unit
# Processing 628000 unit
# Processing 629000 unit
# Processing 630000 unit
# Processing 631000 unit
# Processing 632000 unit
# Processing 633000 unit
# Processing 634000 unit
# Processing 635000 unit
# Processing 636000 unit
# Processing 637000 unit
# Processing 638000 unit
# Processing 639000 unit
# Processing 640000 unit
# Processing 641000 unit
# Processing 642000 unit
# Processing 643000 unit
# Processing 644000 unit
# Processing 645000 unit
# Processing 646000 unit
# Processing 647000 unit
# Processing 648000 unit
# Processing 649000 unit
# Processing 650000 unit
# Processing 651000 unit
# Processing 652000 unit
# Processing 653000 unit
# Processing 654000 unit
# Processing 655000 unit
# Processing 656000 unit
# Processing 657000 unit
# Processing 658000 unit
# Processing 659000 unit
# Processing 660000 unit
# Processing 661000 unit
# Processing 662000 unit
# Processing 663000 unit
# Processing 664000 unit
# Processing 665000 unit
# Processing 666000 unit
# Processing 667000 unit
# Processing 668000 unit
# Processing 669000 unit
# Processing 670000 unit
# Processing 671000 unit
# Processing 672000 unit
# Processing 673000 unit
# Processing 674000 unit
# Processing 675000 unit
# Processing 676000 unit
# Processing 677000 unit
# Processing 678000 unit
# Processing 679000 unit
# Processing 680000 unit
# Processing 681000 unit
# Processing 682000 unit
# Processing 683000 unit
# Processing 684000 unit
# Processing 685000 unit
# Processing 686000 unit
# Processing 687000 unit
# Processing 688000 unit
# Processing 689000 unit
# Processing 690000 unit
# Processing 691000 unit
# Processing 692000 unit
# Processing 693000 unit
# Processing 694000 unit
# Processing 695000 unit
# Processing 696000 unit
# Processing 697000 unit
# Processing 698000 unit
# Processing 699000 unit
# Processing 700000 unit
# Processing 701000 unit
# Processing 702000 unit
# Processing 703000 unit
# Processing 704000 unit
# Processing 705000 unit
# Processing 706000 unit
# Processing 707000 unit
# Processing 708000 unit
# Processing 709000 unit
# Processing 710000 unit
# Processing 711000 unit
# Processing 712000 unit
# Processing 713000 unit
# Processing 714000 unit
# Processing 715000 unit
# Processing 716000 unit
# Processing 717000 unit
# Processing 718000 unit
# Processing 719000 unit
# Processing 720000 unit
# Processing 721000 unit
# Processing 722000 unit
# Processing 723000 unit
# Processing 724000 unit
# Processing 725000 unit
# Processing 726000 unit
# Processing 727000 unit
# Processing 728000 unit
# Processing 729000 unit
# Processing 730000 unit
# Processing 731000 unit
# Processing 732000 unit
# Processing 733000 unit
# Processing 734000 unit
# Processing 735000 unit
# Processing 736000 unit
# Processing 737000 unit
# Processing 738000 unit
# Processing 739000 unit
# Processing 740000 unit
# Processing 741000 unit
# Processing 742000 unit
# Processing 743000 unit
# Processing 744000 unit
# Processing 745000 unit
# Processing 746000 unit
# Processing 747000 unit
# Processing 748000 unit
# Processing 749000 unit
# Processing 750000 unit
# Processing 751000 unit
# Processing 752000 unit
# Processing 753000 unit
# Processing 754000 unit
# Processing 755000 unit
# Processing 756000 unit
# Processing 757000 unit
# Processing 758000 unit
# Processing 759000 unit
# Processing 760000 unit
# Processing 761000 unit
# Processing 762000 unit
# Processing 763000 unit
# Processing 764000 unit
# Processing 765000 unit
# Processing 766000 unit
# Processing 767000 unit
# Processing 768000 unit
# Processing 769000 unit
# Processing 770000 unit
# Processing 771000 unit
# Processing 772000 unit
# Processing 773000 unit
# Processing 774000 unit
# Processing 775000 unit
# Processing 776000 unit
# Processing 777000 unit
# Processing 778000 unit
# Processing 779000 unit
# Processing 780000 unit
# Processing 781000 unit
# Processing 782000 unit
# Processing 783000 unit
# Processing 784000 unit
# Processing 785000 unit
# Processing 786000 unit
# Processing 787000 unit
# Processing 788000 unit
# Processing 789000 unit
# Processing 790000 unit
# Processing 791000 unit
# Processing 792000 unit
# Processing 793000 unit
# Processing 794000 unit
# Processing 795000 unit
# Processing 796000 unit
# Processing 797000 unit
# Processing 798000 unit
# Processing 799000 unit
# Processing 800000 unit
# Processing 801000 unit
# Processing 802000 unit
# Processing 803000 unit
# Processing 804000 unit
# Processing 805000 unit
# Processing 806000 unit
# Processing 807000 unit
# Processing 808000 unit
# Processing 809000 unit
# Processing 810000 unit
# Processing 811000 unit
# Processing 812000 unit
# Processing 813000 unit
# Processing 814000 unit
# Processing 815000 unit
# Processing 816000 unit
# Processing 817000 unit
# Processing 818000 unit
# Processing 819000 unit
# Processing 820000 unit
# Processing 821000 unit
# Processing 822000 unit
# Processing 823000 unit
# Processing 824000 unit
# Processing 825000 unit
# Processing 826000 unit
# Processing 827000 unit
# Processing 828000 unit
# Processing 829000 unit
# Processing 830000 unit
# Processing 831000 unit
# Processing 832000 unit
# Processing 833000 unit
# Processing 834000 unit
# Processing 835000 unit
# Processing 836000 unit
# Processing 837000 unit
# Processing 838000 unit
# Processing 839000 unit
# Processing 840000 unit
# Processing 841000 unit
# Processing 842000 unit
# Processing 843000 unit
# Processing 844000 unit
# Processing 845000 unit
# Processing 846000 unit
# Processing 847000 unit
# Processing 848000 unit
# Processing 849000 unit
# Processing 850000 unit
# Processing 851000 unit
# Processing 852000 unit
# Processing 853000 unit
# Processing 854000 unit
# Processing 855000 unit
# Processing 856000 unit
# Processing 857000 unit
# Processing 858000 unit
# Processing 859000 unit
# Processing 860000 unit
# Processing 861000 unit
# Processing 862000 unit
# Processing 863000 unit
# Processing 864000 unit
# Processing 865000 unit
# Processing 866000 unit
# Processing 867000 unit
# Processing 868000 unit
# Processing 869000 unit
# Processing 870000 unit
# Processing 871000 unit
# Processing 872000 unit
# Processing 873000 unit
# Processing 874000 unit
# Processing 875000 unit
# Processing 876000 unit
# Processing 877000 unit
# Processing 878000 unit
# Processing 879000 unit
# Processing 880000 unit
# Processing 881000 unit
# Processing 882000 unit
# Processing 883000 unit
# Processing 884000 unit
# Processing 885000 unit
# Processing 886000 unit
# Processing 887000 unit
# Processing 888000 unit
# Processing 889000 unit
# Processing 890000 unit
# Processing 891000 unit
# Processing 892000 unit
# Processing 893000 unit
# Processing 894000 unit
# Processing 895000 unit
# Processing 896000 unit
# Processing 897000 unit
# Processing 898000 unit
# Processing 899000 unit
# Processing 900000 unit
# Processing 901000 unit
# Processing 902000 unit
# Processing 903000 unit
# Processing 904000 unit
# Processing 905000 unit
# Processing 906000 unit
# Processing 907000 unit
# Processing 908000 unit
# Processing 909000 unit
# Processing 910000 unit
# Processing 911000 unit
# Processing 912000 unit
# Processing 913000 unit
# Processing 914000 unit
# Processing 915000 unit
# Processing 916000 unit
# Processing 917000 unit
# Processing 918000 unit
# Processing 919000 unit
# Processing 920000 unit
# Processing 921000 unit
# Processing 922000 unit
# Processing 923000 unit
# Processing 924000 unit
# Processing 925000 unit
# Processing 926000 unit
# Processing 927000 unit
# Processing 928000 unit
# Processing 929000 unit
# Processing 930000 unit
# Processing 931000 unit
# Processing 932000 unit
# Processing 933000 unit
# Processing 934000 unit
# Processing 935000 unit
# Processing 936000 unit
# Processing 937000 unit
# Processing 938000 unit
# Processing 939000 unit
# Processing 940000 unit
# Processing 941000 unit
# Processing 942000 unit
# Processing 943000 unit
# Processing 944000 unit
# Processing 945000 unit
# Processing 946000 unit
# Processing 947000 unit
# Processing 948000 unit
# Processing 949000 unit
# Processing 950000 unit
# Processing 951000 unit
# Processing 952000 unit
# Processing 953000 unit
# Processing 954000 unit
# Processing 955000 unit
# Processing 956000 unit
# Processing 957000 unit
# Processing 958000 unit
# Processing 959000 unit
# Processing 960000 unit
# Processing 961000 unit
# Processing 962000 unit
# Processing 963000 unit
# Processing 964000 unit
# Processing 965000 unit
# Processing 966000 unit
# Processing 967000 unit
# Processing 968000 unit
# Processing 969000 unit
# Processing 970000 unit
# Processing 971000 unit
# Processing 972000 unit
# Processing 973000 unit
# Processing 974000 unit
# Processing 975000 unit
# Processing 976000 unit
# Processing 977000 unit
# Processing 978000 unit
# Processing 979000 unit
# Processing 980000 unit
# Processing 981000 unit
# Processing 982000 unit
# Processing 983000 unit
# Processing 984000 unit
# Processing 985000 unit
# Processing 986000 unit
# Processing 987000 unit
# Processing 988000 unit
# Processing 989000 unit
# Processing 990000 unit
# Processing 991000 unit
# Processing 992000 unit
# Processing 993000 unit
# Processing 994000 unit
# Processing 995000 unit
# Processing 996000 unit
# Processing 997000 unit
# Processing 998000 unit
# Processing 999000 unit
# Processing 1000000 unit
# Processing 1001000 unit
# Processing 1002000 unit
# Processing 1003000 unit
# Processing 1004000 unit
# Processing 1005000 unit
# Processing 1006000 unit
# Processing 1007000 unit
# Processing 1008000 unit
# Processing 1009000 unit
# Processing 1010000 unit
# Processing 1011000 unit
# Processing 1012000 unit
# Processing 1013000 unit
# Processing 1014000 unit
# Processing 1015000 unit
# Processing 1016000 unit
# Processing 1017000 unit
# Processing 1018000 unit
# Processing 1019000 unit
# Processing 1020000 unit
# Processing 1021000 unit
# Processing 1022000 unit
# Processing 1023000 unit
# Processing 1024000 unit
# Processing 1025000 unit
# Processing 1026000 unit
# Processing 1027000 unit
# Processing 1028000 unit
# Processing 1029000 unit
# Processing 1030000 unit
# Processing 1031000 unit
# Processing 1032000 unit
# Processing 1033000 unit
# Processing 1034000 unit
# Processing 1035000 unit
# Processing 1036000 unit
# Processing 1037000 unit
# Processing 1038000 unit
# Processing 1039000 unit
# Processing 1040000 unit
# Processing 1041000 unit
# Processing 1042000 unit
# Processing 1043000 unit
# Processing 1044000 unit
# Processing 1045000 unit
# Processing 1046000 unit
# Processing 1047000 unit
# Processing 1048000 unit
# Processing 1049000 unit
# Processing 1050000 unit
# Processing 1051000 unit
# Processing 1052000 unit
# Processing 1053000 unit
# Processing 1054000 unit
# Processing 1055000 unit
# Processing 1056000 unit
# Processing 1057000 unit
# Processing 1058000 unit
# Processing 1059000 unit
# Processing 1060000 unit
# Processing 1061000 unit
# Processing 1062000 unit
# Processing 1063000 unit
# Processing 1064000 unit
# Processing 1065000 unit
# Processing 1066000 unit
# Processing 1067000 unit
# Processing 1068000 unit
# Processing 1069000 unit
# Processing 1070000 unit
# Processing 1071000 unit
# Processing 1072000 unit
# Processing 1073000 unit
# Processing 1074000 unit
# Processing 1075000 unit
# Processing 1076000 unit
# Processing 1077000 unit
# Processing 1078000 unit
# Processing 1079000 unit
# Processing 1080000 unit
# Processing 1081000 unit
# Processing 1082000 unit
# Processing 1083000 unit
# Processing 1084000 unit
# Processing 1085000 unit
# Processing 1086000 unit
# Processing 1087000 unit
# Processing 1088000 unit
# Processing 1089000 unit
# Processing 1090000 unit
# Processing 1091000 unit
# Processing 1092000 unit
# Processing 1093000 unit
# Processing 1094000 unit
# Processing 1095000 unit
# Processing 1096000 unit
# Processing 1097000 unit
# Processing 1098000 unit
# Processing 1099000 unit
# Processing 1100000 unit
# Processing 1101000 unit
# Processing 1102000 unit
# Processing 1103000 unit
# Processing 1104000 unit
# Processing 1105000 unit
# Processing 1106000 unit
# Processing 1107000 unit
# Processing 1108000 unit
# Processing 1109000 unit
# Processing 1110000 unit
# Processing 1111000 unit
# Processing 1112000 unit
# Processing 1113000 unit
# Processing 1114000 unit
# Processing 1115000 unit
# Processing 1116000 unit
# Processing 1117000 unit
# Processing 1118000 unit
# Processing 1119000 unit
# Processing 1120000 unit
# Processing 1121000 unit
# Processing 1122000 unit
# Processing 1123000 unit
# Processing 1124000 unit
# Processing 1125000 unit
# Processing 1126000 unit
# Processing 1127000 unit
# Processing 1128000 unit
# Processing 1129000 unit
# Processing 1130000 unit
# Processing 1131000 unit
# Processing 1132000 unit
# Processing 1133000 unit
# Processing 1134000 unit
# Processing 1135000 unit
# Processing 1136000 unit
# Processing 1137000 unit
# Processing 1138000 unit
# Processing 1139000 unit
# Processing 1140000 unit
# Processing 1141000 unit
# Processing 1142000 unit
# Processing 1143000 unit
# Processing 1144000 unit
# Processing 1145000 unit
# Processing 1146000 unit
# Processing 1147000 unit
# Processing 1148000 unit
# Processing 1149000 unit
# Processing 1150000 unit
# Processing 1151000 unit
# Processing 1152000 unit
# Processing 1153000 unit
# Processing 1154000 unit
# Processing 1155000 unit
# Processing 1156000 unit
# Processing 1157000 unit
# Processing 1158000 unit
# Processing 1159000 unit
# Processing 1160000 unit
# Processing 1161000 unit
# Processing 1162000 unit
# Processing 1163000 unit
# Processing 1164000 unit
# Processing 1165000 unit
# Processing 1166000 unit
# Processing 1167000 unit
# Processing 1168000 unit
# Processing 1169000 unit
# Processing 1170000 unit
# Processing 1171000 unit
# Processing 1172000 unit
# Processing 1173000 unit
# Processing 1174000 unit
# Processing 1175000 unit
# Processing 1176000 unit
# Processing 1177000 unit
# Processing 1178000 unit
# Processing 1179000 unit
# Processing 1180000 unit
# Processing 1181000 unit
# Processing 1182000 unit
# Processing 1183000 unit
# Processing 1184000 unit
# Processing 1185000 unit
# Processing 1186000 unit
# Processing 1187000 unit
# Processing 1188000 unit
# Processing 1189000 unit
# Processing 1190000 unit
# Processing 1191000 unit
# Processing 1192000 unit
# Processing 1193000 unit
# Processing 1194000 unit
# Processing 1195000 unit
# Processing 1196000 unit
# Processing 1197000 unit
# Processing 1198000 unit
# Processing 1199000 unit
# Processing 1200000 unit
# Processing 1201000 unit
# Processing 1202000 unit
# Processing 1203000 unit
# Processing 1204000 unit
# Processing 1205000 unit
# Processing 1206000 unit
# Processing 1207000 unit
# Processing 1208000 unit
# Processing 1209000 unit
# Processing 1210000 unit
# Processing 1211000 unit
# Processing 1212000 unit
# Processing 1213000 unit
# Processing 1214000 unit
# Processing 1215000 unit
# Processing 1216000 unit
# Processing 1217000 unit
# Processing 1218000 unit
# Processing 1219000 unit
# Processing 1220000 unit
# Processing 1221000 unit
# Processing 1222000 unit
# Processing 1223000 unit
# Processing 1224000 unit
# Processing 1225000 unit
# Processing 1226000 unit
# Processing 1227000 unit
# Processing 1228000 unit
# Processing 1229000 unit
# Processing 1230000 unit
# Processing 1231000 unit
# Processing 1232000 unit
# Processing 1233000 unit
# Processing 1234000 unit
# Processing 1235000 unit
# Processing 1236000 unit
# Processing 1237000 unit
# Processing 1238000 unit
# Processing 1239000 unit
# Processing 1240000 unit
# Processing 1241000 unit
# Processing 1242000 unit
# Processing 1243000 unit
# Processing 1244000 unit
# Processing 1245000 unit
# Processing 1246000 unit
# Processing 1247000 unit
# Processing 1248000 unit
# Processing 1249000 unit
# Processing 1250000 unit
# Processing 1251000 unit
# Processing 1252000 unit
# Processing 1253000 unit
# Processing 1254000 unit
# Processing 1255000 unit
# Processing 1256000 unit
# Processing 1257000 unit
# Processing 1258000 unit
# Processing 1259000 unit
# Processing 1260000 unit
# Processing 1261000 unit
# Processing 1262000 unit
# Processing 1263000 unit
# Processing 1264000 unit
# Processing 1265000 unit
# Processing 1266000 unit
# Processing 1267000 unit
# Processing 1268000 unit
# Processing 1269000 unit
# Processing 1270000 unit
# Processing 1271000 unit
# Processing 1272000 unit
# Processing 1273000 unit
# Processing 1274000 unit
# Processing 1275000 unit
# Processing 1276000 unit
# Processing 1277000 unit
# Processing 1278000 unit
# Processing 1279000 unit
# Processing 1280000 unit
# Processing 1281000 unit
# Processing 1282000 unit
# Processing 1283000 unit
# Processing 1284000 unit
# Processing 1285000 unit
# Processing 1286000 unit
# Processing 1287000 unit
# Processing 1288000 unit
# Processing 1289000 unit
# Processing 1290000 unit
# Processing 1291000 unit
# Processing 1292000 unit
# Processing 1293000 unit
# Processing 1294000 unit
# Processing 1295000 unit
# Processing 1296000 unit
# Processing 1297000 unit
# Processing 1298000 unit
# Processing 1299000 unit
# Processing 1300000 unit
# Processing 1301000 unit
# Processing 1302000 unit
# Processing 1303000 unit
# Processing 1304000 unit
# Processing 1305000 unit
# Processing 1306000 unit
# Processing 1307000 unit
# Processing 1308000 unit
# Processing 1309000 unit
# Processing 1310000 unit
# Processing 1311000 unit
# Processing 1312000 unit
# Processing 1313000 unit
# Processing 1314000 unit
# Processing 1315000 unit
# Processing 1316000 unit
# Processing 1317000 unit
# Processing 1318000 unit
# Processing 1319000 unit
# Processing 1320000 unit
# Processing 1321000 unit
# Processing 1322000 unit
# Processing 1323000 unit
# Processing 1324000 unit
# Processing 1325000 unit
# Processing 1326000 unit
# Processing 1327000 unit
# Processing 1328000 unit
# Processing 1329000 unit
# Processing 1330000 unit
# Processing 1331000 unit
# Processing 1332000 unit
# Processing 1333000 unit
# Processing 1334000 unit
# Processing 1335000 unit
# Processing 1336000 unit
# Processing 1337000 unit
# Processing 1338000 unit
# Processing 1339000 unit
# Processing 1340000 unit
# Processing 1341000 unit
# Processing 1342000 unit
# Processing 1343000 unit
# Processing 1344000 unit
# Processing 1345000 unit
# Processing 1346000 unit
# Processing 1347000 unit
# Processing 1348000 unit
# Processing 1349000 unit
# Processing 1350000 unit
# Processing 1351000 unit
# Processing 1352000 unit
# Processing 1353000 unit
# Processing 1354000 unit
# Processing 1355000 unit
# Processing 1356000 unit
# Processing 1357000 unit
# Processing 1358000 unit
# Processing 1359000 unit
# Processing 1360000 unit
# Processing 1361000 unit
# Processing 1362000 unit
# Processing 1363000 unit
# Processing 1364000 unit
# Processing 1365000 unit
# Processing 1366000 unit
# Processing 1367000 unit
# Processing 1368000 unit
# Processing 1369000 unit
# Processing 1370000 unit
# Processing 1371000 unit
# Processing 1372000 unit
# Processing 1373000 unit
# Processing 1374000 unit
# Processing 1375000 unit
# Processing 1376000 unit
# Processing 1377000 unit
# Processing 1378000 unit
# Processing 1379000 unit
# Processing 1380000 unit
# Processing 1381000 unit
# Processing 1382000 unit
# Processing 1383000 unit
# Processing 1384000 unit
# Processing 1385000 unit
# Processing 1386000 unit
# Processing 1387000 unit
# Processing 1388000 unit
# Processing 1389000 unit
# Processing 1390000 unit
# Processing 1391000 unit
# Processing 1392000 unit
# Processing 1393000 unit
# Processing 1394000 unit
# Processing 1395000 unit
# Processing 1396000 unit
# Processing 1397000 unit
# Processing 1398000 unit
# Processing 1399000 unit
# Processing 1400000 unit
# Processing 1401000 unit
# Processing 1402000 unit
# Processing 1403000 unit
# Processing 1404000 unit
# Processing 1405000 unit
# Processing 1406000 unit
# Processing 1407000 unit
# Processing 1408000 unit
# Processing 1409000 unit
# Processing 1410000 unit
# Processing 1411000 unit
# Processing 1412000 unit
# Processing 1413000 unit
# Processing 1414000 unit
# Processing 1415000 unit
# Processing 1416000 unit
# Processing 1417000 unit
# Processing 1418000 unit
# Processing 1419000 unit
# Processing 1420000 unit
# Processing 1421000 unit
# Processing 1422000 unit
# Processing 1423000 unit
# Processing 1424000 unit
# Processing 1425000 unit
# Processing 1426000 unit
# Processing 1427000 unit
# Processing 1428000 unit
# Processing 1429000 unit
# Processing 1430000 unit
# Processing 1431000 unit
# Processing 1432000 unit
# Processing 1433000 unit
# Processing 1434000 unit
# Processing 1435000 unit
# Processing 1436000 unit
# Processing 1437000 unit
# Processing 1438000 unit
# Processing 1439000 unit
# Processing 1440000 unit
# Processing 1441000 unit
# Processing 1442000 unit
# Processing 1443000 unit
# Processing 1444000 unit
# Processing 1445000 unit
# Processing 1446000 unit
# Processing 1447000 unit
# Processing 1448000 unit
# Processing 1449000 unit
# Processing 1450000 unit
# Processing 1451000 unit
# Processing 1452000 unit
# Processing 1453000 unit
# Processing 1454000 unit
# Processing 1455000 unit
# Processing 1456000 unit
# Processing 1457000 unit
# Processing 1458000 unit
# Processing 1459000 unit
# Processing 1460000 unit
# Processing 1461000 unit
# Processing 1462000 unit
# Processing 1463000 unit
# Processing 1464000 unit
# Processing 1465000 unit
# Processing 1466000 unit
# Processing 1467000 unit
# Processing 1468000 unit
# Processing 1469000 unit
# Processing 1470000 unit
# Processing 1471000 unit
# Processing 1472000 unit
# Processing 1473000 unit
# Processing 1474000 unit
# Processing 1475000 unit
# Processing 1476000 unit
# Processing 1477000 unit
# Processing 1478000 unit
# Processing 1479000 unit
# Processing 1480000 unit
# Processing 1481000 unit
# Processing 1482000 unit
# Processing 1483000 unit
# Processing 1484000 unit
# Processing 1485000 unit
# Processing 1486000 unit
# Processing 1487000 unit
# Processing 1488000 unit
# Processing 1489000 unit
# Processing 1490000 unit
# Processing 1491000 unit
# Processing 1492000 unit
# Processing 1493000 unit
# Processing 1494000 unit
# Processing 1495000 unit
# Processing 1496000 unit
# Processing 1497000 unit
# Processing 1498000 unit
# Processing 1499000 unit

# %%
clean_data
# Out:
#          Label                                          Sentences
# 0            0                                  think hate summer
# 1            1                                    time subway run
# 2            0                      feel terrible definitely sick
# 3            0  not wait dare quotrealquot job probably go wai...
# 4            0       battery low20iphone 3 g realy battery killer
# ...        ...                                                ...
# 1499995      1                     enjoy new old dub funk acquire
# 1499996      1                                    weather awesome
# 1499997      1                                           margaret
# 1499998      0  chris sweet weepy aww wish people not hard tim...
# 1499999      0                         finger toe cross good come
#
# [1500000 rows x 2 columns]

# %%
clean_data.to_csv('clean_data.csv',index=False)
