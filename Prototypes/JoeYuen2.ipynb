# %%
# install dependencies
# this cell might take some time to run, be patient
import sys

# install spacy
# !{sys.executable} -m pip install spacy
# install spacy en module
# !{sys.executable} -m spacy download en
# Out:
# Requirement already satisfied: spacy in /Users/jianwei/opt/anaconda3/lib/python3.7/site-packages (2.2.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/jianwei/opt/anaconda3/lib/python3.7/site-packages (from spacy) (1.0.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/jianwei/opt/anaconda3/lib/python3.7/site-packages (from spacy) (3.0.2)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /Users/jianwei/opt/anaconda3/lib/python3.7/site-packages (from spacy) (1.1.3)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in /Users/jianwei/opt/anaconda3/lib/python3.7/site-packages (from spacy) (0.23)
# Requirement already satisfied: thinc<7.4.0,>=7.3.0 in /Users/jianwei/opt/anaconda3/lib/python3.7/site-packages (from spacy) (7.3.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/jianwei/opt/anaconda3/lib/python3.7/site-packages (from spacy) (2.22.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.3.0 in /Users/jianwei/opt/anaconda3/lib/python3.7/site-packages (from spacy) (0.4.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/jianwei/opt/anaconda3/lib/python3.7/site-packages (from spacy) (2.0.2)
# Requirement already satisfied: srsly<1.1.0,>=0.1.0 in /Users/jianwei/opt/anaconda3/lib/python3.7/site-packages (from spacy) (0.2.0)
# Requirement already satisfied: setuptools in /Users/jianwei/opt/anaconda3/lib/python3.7/site-packages (from spacy) (41.4.0)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /Users/jianwei/opt/anaconda3/lib/python3.7/site-packages (from spacy) (0.4.1)
# Requirement already satisfied: numpy>=1.15.0 in /Users/jianwei/opt/anaconda3/lib/python3.7/site-packages (from spacy) (1.17.2)
# Requirement already satisfied: zipp>=0.5 in /Users/jianwei/opt/anaconda3/lib/python3.7/site-packages (from importlib-metadata>=0.20; python_version < "3.8"->spacy) (0.6.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.10.0 in /Users/jianwei/opt/anaconda3/lib/python3.7/site-packages (from thinc<7.4.0,>=7.3.0->spacy) (4.36.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/jianwei/opt/anaconda3/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.24.2)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Users/jianwei/opt/anaconda3/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /Users/jianwei/opt/anaconda3/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jianwei/opt/anaconda3/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2019.9.11)
# Requirement already satisfied: more-itertools in /Users/jianwei/opt/anaconda3/lib/python3.7/site-packages (from zipp>=0.5->importlib-metadata>=0.20; python_version < "3.8"->spacy) (7.2.0)
# Requirement already satisfied: en_core_web_sm==2.2.0 from https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.2.0/en_core_web_sm-2.2.0.tar.gz#egg=en_core_web_sm==2.2.0 in /Users/jianwei/opt/anaconda3/lib/python3.7/site-packages (2.2.0)
# Requirement already satisfied: spacy>=2.2.0 in /Users/jianwei/opt/anaconda3/lib/python3.7/site-packages (from en_core_web_sm==2.2.0) (2.2.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/jianwei/opt/anaconda3/lib/python3.7/site-packages (from spacy>=2.2.0->en_core_web_sm==2.2.0) (3.0.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/jianwei/opt/anaconda3/lib/python3.7/site-packages (from spacy>=2.2.0->en_core_web_sm==2.2.0) (1.0.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/jianwei/opt/anaconda3/lib/python3.7/site-packages (from spacy>=2.2.0->en_core_web_sm==2.2.0) (2.0.2)
# Requirement already satisfied: numpy>=1.15.0 in /Users/jianwei/opt/anaconda3/lib/python3.7/site-packages (from spacy>=2.2.0->en_core_web_sm==2.2.0) (1.17.2)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in /Users/jianwei/opt/anaconda3/lib/python3.7/site-packages (from spacy>=2.2.0->en_core_web_sm==2.2.0) (0.23)
# Requirement already satisfied: wasabi<1.1.0,>=0.3.0 in /Users/jianwei/opt/anaconda3/lib/python3.7/site-packages (from spacy>=2.2.0->en_core_web_sm==2.2.0) (0.4.0)
# Requirement already satisfied: srsly<1.1.0,>=0.1.0 in /Users/jianwei/opt/anaconda3/lib/python3.7/site-packages (from spacy>=2.2.0->en_core_web_sm==2.2.0) (0.2.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/jianwei/opt/anaconda3/lib/python3.7/site-packages (from spacy>=2.2.0->en_core_web_sm==2.2.0) (2.22.0)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /Users/jianwei/opt/anaconda3/lib/python3.7/site-packages (from spacy>=2.2.0->en_core_web_sm==2.2.0) (0.4.1)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /Users/jianwei/opt/anaconda3/lib/python3.7/site-packages (from spacy>=2.2.0->en_core_web_sm==2.2.0) (1.1.3)
# Requirement already satisfied: thinc<7.4.0,>=7.3.0 in /Users/jianwei/opt/anaconda3/lib/python3.7/site-packages (from spacy>=2.2.0->en_core_web_sm==2.2.0) (7.3.1)
# Requirement already satisfied: setuptools in /Users/jianwei/opt/anaconda3/lib/python3.7/site-packages (from spacy>=2.2.0->en_core_web_sm==2.2.0) (41.4.0)
# Requirement already satisfied: zipp>=0.5 in /Users/jianwei/opt/anaconda3/lib/python3.7/site-packages (from importlib-metadata>=0.20; python_version < "3.8"->spacy>=2.2.0->en_core_web_sm==2.2.0) (0.6.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Users/jianwei/opt/anaconda3/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.0->en_core_web_sm==2.2.0) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jianwei/opt/anaconda3/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.0->en_core_web_sm==2.2.0) (2019.9.11)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/jianwei/opt/anaconda3/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.0->en_core_web_sm==2.2.0) (1.24.2)
# Requirement already satisfied: idna<2.9,>=2.5 in /Users/jianwei/opt/anaconda3/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.0->en_core_web_sm==2.2.0) (2.8)
# Requirement already satisfied: tqdm<5.0.0,>=4.10.0 in /Users/jianwei/opt/anaconda3/lib/python3.7/site-packages (from thinc<7.4.0,>=7.3.0->spacy>=2.2.0->en_core_web_sm==2.2.0) (4.36.1)
# Requirement already satisfied: more-itertools in /Users/jianwei/opt/anaconda3/lib/python3.7/site-packages (from zipp>=0.5->importlib-metadata>=0.20; python_version < "3.8"->spacy>=2.2.0->en_core_web_sm==2.2.0) (7.2.0)
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')
# ✔ Linking successful
# /Users/jianwei/opt/anaconda3/lib/python3.7/site-packages/en_core_web_sm -->
# /Users/jianwei/opt/anaconda3/lib/python3.7/site-packages/spacy/data/en
# You can now load the model via spacy.load('en')

# %%
CUSTOMISED_STOP_WORDS = set(
    """
    a about above across after afterwards again all almost alone along
    already also although always am among amongst amount an and another any anyhow
    anyone anything anyway anywhere are around as at
    back be became because become becomes becoming been before beforehand behind
    being below beside besides between beyond both bottom but by
    call can cannot ca could
    did do does doing done down due during
    each eight either eleven else elsewhere empty enough even ever every
    everyone everything everywhere except
    few fifteen fifty first five for former formerly forty four from front full
    further
    get give go
    had has have he hence her here hereafter hereby herein hereupon hers herself
    him himself his how however hundred
    i if in indeed into is it its itself
    keep
    last latter latterly least less
    just
    made make many may me meanwhile might mine more moreover most mostly move much
    must my myself
    name namely neither never nevertheless next nine now
    of off often on once one only onto or other others otherwise our ours ourselves
    out over own
    part per perhaps please put
    quite
    rather re really regarding
    same say see seem seemed seeming seems serious several she should show side
    since six sixty so some somehow someone something sometime sometimes somewhere
    still such
    take ten than that the their them themselves then thence there thereafter
    thereby therefore therein thereupon these they third this those though three
    through throughout thru thus to together too top toward towards twelve twenty
    two
    under until up unless upon us used using
    various very very via was we well were what whatever when whence whenever where
    whereafter whereas whereby wherein whereupon wherever whether which while
    whither who whoever whole whom whose why will with within without would
    yet you your yours yourself yourselves
    """.split()
)

customised_contractions = ["'d", "'ll", "'m", "'re", "'s", "'ve"]
CUSTOMISED_STOP_WORDS.update(customised_contractions)

# %%
# run the commands below in terminal to install dependencies
# pip install spacy
# python -m spacy download en
import spacy
from spacy.lang.en import English
from spacy.lang.en.stop_words import STOP_WORDS
import string

nlp_sw = English()
nlp_n = spacy.load("en_core_web_sm")

removable_char = list(string.punctuation) + ["\n", "\r"]

# text arguement in string
# remove stop words of the provided text
# return a list of words in small letters in the text without stop words and punctuations
def remove_stop_words(text):
    text = text.lower()
    token_doc = nlp_sw(text)
    clean_text = []
    for token in token_doc:
        token_text = token.text
        token_text = token_text.replace(" ", "")
        token_text = "not" if token_text == "n't" else token_text
        if not(token_text in CUSTOMISED_STOP_WORDS or token_text in removable_char):
            if token_text and not(token_text.isspace()):
                tmp_text = token_text[1:] if token_text[0] in removable_char else token_text
                if tmp_text and not(tmp_text.isspace()):
                    clean_text.append(tmp_text)
    return clean_text

# text arguement in string
# normalise the text
# return a list of words in small letters in the normalised text
def normalise_text(text):
    text = text.lower()
    token_doc = nlp_n(text)
    normalised_text = []
    for token in token_doc:
        lemma = token.lemma_
        if not(lemma == "-PRON-"):
            normalised_text.append(lemma)
    return normalised_text

# %%
text = "Social media platforms are becoming an integral part of people’s life. They reflect the user’s personal life. People like to share happiness, joy, and sadness on social media. These platforms are used for researchers to identify the causes of depression and detect it."

normalise_text(" ".join(remove_stop_words("not happy")))
# Out:
# ['not', 'happy']

# %%
remove_stop_words("not happy")
# Out:
# ['not', 'happy']

# %%
# reading the csv file
import pandas as pd
df = pd.read_csv('training.1600000.processed.noemoticon.csv',encoding = "ISO-8859-1")
df
# Out:
#          0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY  \
# 0        0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 1        0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 2        0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 3        0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4        0  1467811372  Mon Apr 06 22:20:00 PDT 2009  NO_QUERY
# ...     ..         ...                           ...       ...
# 1599994  4  2193601966  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599995  4  2193601969  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599996  4  2193601991  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599997  4  2193602064  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599998  4  2193602129  Tue Jun 16 08:40:50 PDT 2009  NO_QUERY
#
#          _TheSpecialOne_  \
# 0          scotthamilton
# 1               mattycus
# 2                ElleCTF
# 3                 Karoli
# 4               joy_wolf
# ...                  ...
# 1599994  AmandaMarie1028
# 1599995      TheWDBoards
# 1599996           bpbabe
# 1599997     tinydiamondz
# 1599998   RyanTrevMorris
#
#         @switchfoot http://twitpic.com/2y1zl - Awww, that's a bummer.  You shoulda got David Carr of Third Day to do it. ;D
# 0        is upset that he can't update his Facebook by ...
# 1        @Kenichan I dived many times for the ball. Man...
# 2          my whole body feels itchy and like its on fire
# 3        @nationwideclass no, it's not behaving at all....
# 4                            @Kwesidei not the whole crew
# ...                                                    ...
# 1599994  Just woke up. Having no school is the best fee...
# 1599995  TheWDB.com - Very cool to hear old Walt interv...
# 1599996  Are you ready for your MoJo Makeover? Ask me f...
# 1599997  Happy 38th Birthday to my boo of alll time!!! ...
# 1599998  happy #charitytuesday @theNSPCC @SparksCharity...
#
# [1599999 rows x 6 columns]

# %%
#checking the strucuture of the dataset
for key in df :
    print(key)
# Out:
# 0
# 1467810369
# Mon Apr 06 22:19:45 PDT 2009
# NO_QUERY
# _TheSpecialOne_
# @switchfoot http://twitpic.com/2y1zl - Awww, that's a bummer.  You shoulda got David Carr of Third Day to do it. ;D

# %%
# removing unwanted columns of dataset
df = df[['0',"@switchfoot http://twitpic.com/2y1zl - Awww, that's a bummer.  You shoulda got David Carr of Third Day to do it. ;D"]]
df
# Out:
#          0  \
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
# ...     ..
# 1599994  4
# 1599995  4
# 1599996  4
# 1599997  4
# 1599998  4
#
#         @switchfoot http://twitpic.com/2y1zl - Awww, that's a bummer.  You shoulda got David Carr of Third Day to do it. ;D
# 0        is upset that he can't update his Facebook by ...
# 1        @Kenichan I dived many times for the ball. Man...
# 2          my whole body feels itchy and like its on fire
# 3        @nationwideclass no, it's not behaving at all....
# 4                            @Kwesidei not the whole crew
# ...                                                    ...
# 1599994  Just woke up. Having no school is the best fee...
# 1599995  TheWDB.com - Very cool to hear old Walt interv...
# 1599996  Are you ready for your MoJo Makeover? Ask me f...
# 1599997  Happy 38th Birthday to my boo of alll time!!! ...
# 1599998  happy #charitytuesday @theNSPCC @SparksCharity...
#
# [1599999 rows x 2 columns]

# %%
#change name of Columns
df.columns=['Label','Sentences']

# %%
#save file to csv
df.to_csv('training_data.csv',index=False)

# %%
df = pd.read_csv('training_data.csv')

# %%
df
# Out:
#          Label                                          Sentences
# 0            0  is upset that he can't update his Facebook by ...
# 1            0  @Kenichan I dived many times for the ball. Man...
# 2            0    my whole body feels itchy and like its on fire
# 3            0  @nationwideclass no, it's not behaving at all....
# 4            0                      @Kwesidei not the whole crew
# ...        ...                                                ...
# 1599994      4  Just woke up. Having no school is the best fee...
# 1599995      4  TheWDB.com - Very cool to hear old Walt interv...
# 1599996      4  Are you ready for your MoJo Makeover? Ask me f...
# 1599997      4  Happy 38th Birthday to my boo of alll time!!! ...
# 1599998      4  happy #charitytuesday @theNSPCC @SparksCharity...
#
# [1599999 rows x 2 columns]

# %%
# 0 = negative, 2 = neutral, 4 = positive
number_of_data = 100000
data_negative = df[df.Label == 0][:int(number_of_data/2)]
data_positive = df[df.Label == 4][:int(number_of_data/2)]
data_positive["Label"] = 1
df_row_merged = pd.concat([data_negative, data_positive], ignore_index=True)
df_row_merged
# Out:
#        Label                                          Sentences
# 0          0  is upset that he can't update his Facebook by ...
# 1          0  @Kenichan I dived many times for the ball. Man...
# 2          0    my whole body feels itchy and like its on fire
# 3          0  @nationwideclass no, it's not behaving at all....
# 4          0                      @Kwesidei not the whole crew
# ...      ...                                                ...
# 99995      1  Now need 8 followers to compleate 1000  Follow...
# 99996      1  I knew I had to explain something to my friend...
# 99997      1                 done tweeting..... til tomorrow..
# 99998      1  @cmozilo Act II set is pretty breath-taking -L...
# 99999      1  if you don't have an artfire account to sell y...
#
# [100000 rows x 2 columns]

# %%
df_row_merged = df_row_merged.sample(frac=1).reset_index(drop=True)
df_row_merged
# Out:
#        Label                                          Sentences
# 0          1  am i the only one in hvis world, who's scared ...
# 1          1  @Monkeytraining haha naw. the model drove this...
# 2          1  @erinmusicluver night, can't wait for your vid...
# 3          0  i hate being bored and alone. someone go to th...
# 4          0                                   Ice baths hurt.
# ...      ...                                                ...
# 99995      0  Another loser: just lost the game  http://tiny...
# 99996      1  @rubypurple sorry twitterberry fails, glad to ...
# 99997      1  Just got back from town ;) Bought a few DVDs  ...
# 99998      1  @envirotainment oi, wait for the 1st of June! ...
# 99999      1  shit i think i have to write my own pagination...
#
# [100000 rows x 2 columns]

# %%
training_data = df_row_merged[:int(len(df_row_merged)*0.7)]
test_data = df_row_merged[int(len(df_row_merged)*0.7):]
training_data
# Out:
#        Label                                          Sentences
# 0          1  am i the only one in hvis world, who's scared ...
# 1          1  @Monkeytraining haha naw. the model drove this...
# 2          1  @erinmusicluver night, can't wait for your vid...
# 3          0  i hate being bored and alone. someone go to th...
# 4          0                                   Ice baths hurt.
# ...      ...                                                ...
# 69995      0  @transbay &quot;SFMTA Budget Proposal Hearing:...
# 69996      0                            gah. sorry aboutt that
# 69997      1  is wondering what the heck to do with this... ...
# 69998      0  @reoracer I was crawling out of bed about the ...
# 69999      0     first day back to work and the sun comes out.
#
# [70000 rows x 2 columns]

# %%
test_data
# Out:
#        Label                                          Sentences
# 70000      1  thanks for all the input @ncvbxfgf, @jogabenit...
# 70001      0  @nick_carter http://twitpic.com/3kp8y - wow, I...
# 70002      0  Writing up stuff for hospital visit tomorrow. ...
# 70003      0  @KarsentheSlater I'm getting pissy lately - I ...
# 70004      0  @mauibaby10 I'm driving the x5, cuz my baby wa...
# ...      ...                                                ...
# 99995      0  Another loser: just lost the game  http://tiny...
# 99996      1  @rubypurple sorry twitterberry fails, glad to ...
# 99997      1  Just got back from town ;) Bought a few DVDs  ...
# 99998      1  @envirotainment oi, wait for the 1st of June! ...
# 99999      1  shit i think i have to write my own pagination...
#
# [30000 rows x 2 columns]

# %%
# remove url in tweets
# remove tag (@) in tweets
# remove hashtags (#) in tweets
# remove stopwords
# normalise text
# this cell might take some time to run, be patient
import re
import string

url_pattern = re.compile(".*https?:\/\/")
hashtag_pattern = re.compile("#[a-z\d-]+")
tag_pattern = re.compile("^@")
punc = string.punctuation
punc = punc.replace("-", "")
punc += "“”"
punc = punc.replace ("'","")

pd.options.mode.chained_assignment = None

def process_text(text):
    tmp_no_url_hashtag = []
    for word in re.split(' |\r|\n', text):
        if url_pattern.match(word) or tag_pattern.match(word) or hashtag_pattern.match(word):
            continue
        else:
            clean_word = word.translate(str.maketrans("","", punc))
            clean_word = clean_word.replace("’","'")
            tmp_no_url_hashtag.append(clean_word)
    tmp = " ".join(tmp_no_url_hashtag)
    without_stopwords = " ".join(remove_stop_words(tmp))
    processed = " ".join(normalise_text(without_stopwords))
    return processed

for i in range (len(training_data["Sentences"])):
    training_data["Sentences"][i] = process_text(training_data["Sentences"][i])
    if i % 1000 == 0:
        print ("Processing", i, "unit")

# %%
training_data
# Out:
#        Label                                          Sentences
# 0          1        hvis world scare ladybug xd lmao guess plt3
# 1          1                          haha naw model drive time
# 2          1                               night not wait video
# 3          0                                    hate bored park
# 4          0                                      ice bath hurt
# ...      ...                                                ...
# 69995      0  quotsfmta budget proposal hearing tomorrow apr...
# 69996      0                                   gah sorry aboutt
# 69997      1                   wonder heck crave chip salsa mmm
# 69998      0  crawl bed time not work night feel lazy guess ...
# 69999      0                                  day work sun come
#
# [70000 rows x 2 columns]

# %%
validation_data = training_data[:int(len(training_data)*0.1)]
training_data = training_data[int(len(training_data)*0.1):]

# %%
import numpy as np
train_x_val = np.asarray(training_data["Sentences"])
train_y_val = np.asarray(training_data["Label"])
valid_x_val = np.asarray(validation_data["Sentences"])
valid_y_val = np.asarray(validation_data["Label"])

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import tensorflow as tf
import tensorflow_hub as hub
import tensorflow_datasets as tfds
embedding = "https://tfhub.dev/google/tf2-preview/gnews-swivel-20dim/1"
# embedding = "https://tfhub.dev/google/tf2-preview/nnlm-en-dim50/1"
# embedding = "https://tfhub.dev/google/tf2-preview/nnlm-en-dim128/1"
hub_layer = hub.KerasLayer(embedding, input_shape=[], 
                           dtype=tf.string, trainable=True)
# hub_layer(training_data["Sentences"][:3])

# %%
model = tf.keras.Sequential()
model.add(hub_layer)
model.add(tf.keras.layers.Dense(50, activation='relu'))
# model.add(tf.keras.layers.Dense(10, activation='relu'))
model.add(tf.keras.layers.Dense(1, activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# keras_layer_3 (KerasLayer)   (None, 20)                400020
# _________________________________________________________________
# dense_14 (Dense)             (None, 50)                1050
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 51
# =================================================================
# Total params: 401,121
# Trainable params: 401,121
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
history = model.fit(train_x_val,
                    train_y_val,
                    epochs=20,
                    validation_data=(valid_x_val, valid_y_val),
                    verbose=1)
# Out:
# Train on 63000 samples, validate on 7000 samples
# Epoch 1/20
# 63000/63000 [==============================] - 13s 205us/sample - loss: 0.5621 - accuracy: 0.7086 - val_loss: 0.5300 - val_accuracy: 0.7373
# Epoch 2/20
# 63000/63000 [==============================] - 10s 162us/sample - loss: 0.4990 - accuracy: 0.7580 - val_loss: 0.5296 - val_accuracy: 0.7413
# Epoch 3/20
# 63000/63000 [==============================] - 10s 165us/sample - loss: 0.4802 - accuracy: 0.7700 - val_loss: 0.5268 - val_accuracy: 0.7411
# Epoch 4/20
# 63000/63000 [==============================] - 11s 167us/sample - loss: 0.4682 - accuracy: 0.7754 - val_loss: 0.5340 - val_accuracy: 0.7429
# Epoch 5/20
# 63000/63000 [==============================] - 11s 168us/sample - loss: 0.4579 - accuracy: 0.7826 - val_loss: 0.5429 - val_accuracy: 0.7430
# Epoch 6/20
# 63000/63000 [==============================] - 10s 159us/sample - loss: 0.4481 - accuracy: 0.7882 - val_loss: 0.5482 - val_accuracy: 0.7399
# Epoch 7/20
# 63000/63000 [==============================] - 10s 159us/sample - loss: 0.4389 - accuracy: 0.7931 - val_loss: 0.5548 - val_accuracy: 0.7351
# Epoch 8/20
# 63000/63000 [==============================] - 10s 161us/sample - loss: 0.4289 - accuracy: 0.7984 - val_loss: 0.5685 - val_accuracy: 0.7319
# Epoch 9/20
# 63000/63000 [==============================] - 10s 162us/sample - loss: 0.4188 - accuracy: 0.8046 - val_loss: 0.5760 - val_accuracy: 0.7310
# Epoch 10/20
# 63000/63000 [==============================] - 11s 171us/sample - loss: 0.4092 - accuracy: 0.8095 - val_loss: 0.5889 - val_accuracy: 0.7283
# Epoch 11/20
# 63000/63000 [==============================] - 11s 170us/sample - loss: 0.3991 - accuracy: 0.8155 - val_loss: 0.6011 - val_accuracy: 0.7231
# Epoch 12/20
# 63000/63000 [==============================] - 11s 175us/sample - loss: 0.3892 - accuracy: 0.8197 - val_loss: 0.6176 - val_accuracy: 0.7267
# Epoch 13/20
# 63000/63000 [==============================] - 11s 170us/sample - loss: 0.3799 - accuracy: 0.8261 - val_loss: 0.6296 - val_accuracy: 0.7184
# Epoch 14/20
# 63000/63000 [==============================] - 11s 180us/sample - loss: 0.3695 - accuracy: 0.8310 - val_loss: 0.6551 - val_accuracy: 0.7170
# Epoch 15/20
# 63000/63000 [==============================] - 12s 186us/sample - loss: 0.3599 - accuracy: 0.8379 - val_loss: 0.6661 - val_accuracy: 0.7150
# Epoch 16/20
# 63000/63000 [==============================] - 11s 174us/sample - loss: 0.3501 - accuracy: 0.8431 - val_loss: 0.6860 - val_accuracy: 0.7144
# Epoch 17/20
# 63000/63000 [==============================] - 10s 164us/sample - loss: 0.3407 - accuracy: 0.8484 - val_loss: 0.7014 - val_accuracy: 0.7146
# Epoch 18/20
# 63000/63000 [==============================] - 11s 167us/sample - loss: 0.3309 - accuracy: 0.8543 - val_loss: 0.7287 - val_accuracy: 0.7109
# Epoch 19/20
# 63000/63000 [==============================] - 10s 164us/sample - loss: 0.3224 - accuracy: 0.8575 - val_loss: 0.7472 - val_accuracy: 0.7076
# Epoch 20/20
# 63000/63000 [==============================] - 11s 168us/sample - loss: 0.3135 - accuracy: 0.8618 - val_loss: 0.7689 - val_accuracy: 0.7073

# %%
test_x_val = np.asarray(test_data["Sentences"])
test_y_val = np.asarray(test_data["Label"])

# %%
results = model.evaluate(test_x_val, test_y_val)
# Out:
# 30000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...

# %%
print(results)
# Out:
# [1.571012688446045, 0.60286665]

# %%
def make_prediction(text):
    predict = model.predict([process_text(text)])
    return predict[0][0]

# %%
make_prediction('My teacher praised me')
# Out:
# 0.5239538
